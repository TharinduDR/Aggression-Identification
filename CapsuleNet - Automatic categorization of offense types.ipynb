# %% [markdown]
# ## Automatic categorization of offense types
#
# This is the task 'b' in Task 6: OffensEval: Identifying and Categorizing Offensive Language in Social Media in SemEval 2019. We have explored how a capsule network can be used in automatic categorization of offense types.

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn import metrics

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import *
from keras.models import *
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.initializers import *
from keras.optimizers import *
import keras.backend as K
from keras.callbacks import *
import tensorflow as tf
import os
import time
import gc
import re
from unidecode import unidecode

# %% [markdown]
# ### Loading the training and testing files

# %%
# Filter the non offensive posts in the training set
train = pd.read_csv("Data/training/offenseval-training-v1.tsv", sep='\t')
train = train.loc[train['subtask_a'] == 'OFF']

test_tweets = pd.read_csv("Data/testing/testset-taskb.tsv", sep='\t')
test_labels = pd.read_csv("Data/testing/labels_test-b.csv", header=-1, names = ["id", "subtask_b"])

test = pd.merge(test_tweets, test_labels, on=['id','id'])
print("Train shape : ", train.shape)
print("Test shape : ", test.shape)
# Out:
# Train shape :  (4400, 5)
# Test shape :  (240, 3)

# %% [markdown]
# Changing case of the tweets to lower case, since the embedding model only has lower case words

# %%
train["tweet"] = train["tweet"].str.lower()
test["tweet"] = test["tweet"].str.lower()

# %% [markdown]
# cleaning the puncutation marks

# %%
puncts = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£', 
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', 
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', 
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', 
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√', ]

def clean_text(x):

    x = str(x)
    for punct in puncts:
        x = x.replace(punct, f' {punct} ')
    return x


train["tweet"] = train["tweet"].apply(lambda x: clean_text(x))
test["tweet"] = test["tweet"].apply(lambda x: clean_text(x))

# %%
## some config values 
embed_size = 300 # how big is each word vector
max_features = None # how many unique words to use (i.e num rows in embedding vector)
maxlen = 72 # max number of words in a question to use #99.99%

## fill up the missing values
X = train["tweet"].fillna("_na_").values
X_test = test["tweet"].fillna("_na_").values

## Tokenize the sentences
tokenizer = Tokenizer(num_words=max_features, filters='')
tokenizer.fit_on_texts(list(X))

X = tokenizer.texts_to_sequences(X)
X_test = tokenizer.texts_to_sequences(X_test)

## Pad the sentences 
X = pad_sequences(X, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

## Get the target values
Y = train['subtask_b'].values
Y
# Out:
# array(['UNT', 'TIN', 'UNT', ..., 'TIN', 'TIN', 'UNT'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(Y)
encoded_Y = le.transform(Y)
encoded_Y
# Out:
# array([1, 0, 1, ..., 0, 0, 1])

# %% [markdown]
# Building the Embedding matrix

# %%
word_index = tokenizer.word_index
max_features = len(word_index)+1
def load_glove(word_index):
    EMBEDDING_FILE = '/data/glove/glove.840B.300d.txt'
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if o.split(" ")[0] in word_index)

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    embedding_matrix = np.random.normal(emb_mean, emb_std, (max_features, embed_size))
    for word, i in word_index.items():
        if i >= max_features: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector
            
    return embedding_matrix 
    
def load_fasttext(word_index):    
    EMBEDDING_FILE = '/data/fasttext/crawl-300d-2M-subword.vec'
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if len(o)>100 and o.split(" ")[0] in word_index )

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    embedding_matrix = np.random.normal(emb_mean, emb_std, (max_features, embed_size))
    for word, i in word_index.items():
        if i >= max_features: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector

    return embedding_matrix

# %% [markdown]
# Only Glove vectors have been used in embedding matrix. Can explore it further in future

# %%
embedding_matrix = load_glove(word_index)

# %% [markdown]
# Definning the Capsule Layer in Keras

# %%
def squash(x, axis=-1):
    s_squared_norm = K.sum(K.square(x), axis, keepdims=True)
    scale = K.sqrt(s_squared_norm + K.epsilon())
    return x / scale

# %%
class Capsule(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, kernel_size=(9, 1), share_weights=True,
                 activation='default', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.kernel_size = kernel_size
        self.share_weights = share_weights
        if activation == 'default':
            self.activation = squash
        else:
            self.activation = Activation(activation)

    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     # shape=self.kernel_size,
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
            
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule, self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))
        # final u_hat_vecs.shape = [None, num_capsule, input_num_capsule, dim_capsule]

        b = K.zeros_like(u_hat_vecs[:, :, :, 0])  # shape = [None, num_capsule, input_num_capsule]
        for i in range(self.routings):
            b = K.permute_dimensions(b, (0, 2, 1))  # shape = [None, input_num_capsule, num_capsule]
            c = K.softmax(b)
            c = K.permute_dimensions(c, (0, 2, 1))
            b = K.permute_dimensions(b, (0, 2, 1))
            outputs = self.activation(K.batch_dot(c, u_hat_vecs, [2, 2]))
            if i < self.routings - 1:
                b = K.batch_dot(outputs, u_hat_vecs, [2, 3])

        return outputs

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %% [markdown]
# Capsule Layer with a Bi directional GRU. Architecture found in text classification project.

# %%
def capsule():
    K.clear_session()       
    inp = Input(shape=(maxlen,))
    x = Embedding(max_features, embed_size, weights=[embedding_matrix], trainable=False)(inp)
    x = SpatialDropout1D(rate=0.2)(x)
    x = Bidirectional(GRU(100, return_sequences=True, 
                                kernel_initializer=glorot_normal(seed=12300), recurrent_initializer=orthogonal(gain=1.0, seed=10000)))(x)

    x = Capsule(num_capsule=10, dim_capsule=10, routings=4, share_weights=True)(x)
    x = Flatten()(x)

    x = Dense(100, activation="relu", kernel_initializer=glorot_normal(seed=12300))(x)
    x = Dropout(0.12)(x)
    x = BatchNormalization()(x)

    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer=Adam(),)
    return model

# %%
def f1_smart(y_true, y_pred):
    args = np.argsort(y_pred)
    tp = y_true.sum()
    fs = (tp - np.cumsum(y_true[args[:-1]])) / np.arange(y_true.shape[0] + tp - 1, tp, -1)
    res_idx = np.argmax(fs)
    return 2 * fs[res_idx], (y_pred[args[res_idx]] + y_pred[args[res_idx + 1]]) / 2

# %% [markdown]
# Training with early stopping and reducing learning rate on plateu. In each fold values for the test set is also predicted, And after the process, predicted values for the test file would be mean from each fold

# %%
kfold = StratifiedKFold(n_splits=5, random_state=10, shuffle=True)
bestscore = []
y_test = np.zeros((X_test.shape[0], ))
for i, (train_index, valid_index) in enumerate(kfold.split(X, encoded_Y)):
    X_train, X_val, Y_train, Y_val = X[train_index], X[valid_index], encoded_Y[train_index], encoded_Y[valid_index]
    filepath="Models/capsule_net_weights_best.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=2, save_best_only=True, mode='min')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.6, patience=1, min_lr=0.0001, verbose=2)
    earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=2, mode='auto')
    callbacks = [checkpoint, reduce_lr]
    model = capsule()
    if i == 0:print(model.summary()) 
    model.fit(X_train, Y_train, batch_size=64, epochs=20, validation_data=(X_val, Y_val), verbose=2, callbacks=callbacks, 
             )
    model.load_weights(filepath)
    y_pred = model.predict([X_val], batch_size=64, verbose=2)
    y_test += np.squeeze(model.predict([X_test], batch_size=64, verbose=2))/5
    f1, threshold = f1_smart(np.squeeze(Y_val), np.squeeze(y_pred))
    print('Optimal F1: {:.4f} at threshold: {:.4f}'.format(f1, threshold))
    bestscore.append(threshold)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 72)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 72, 300)           3188700
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 72, 300)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 72, 200)           240600
# _________________________________________________________________
# capsule_1 (Capsule)          (None, 10, 10)            20000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100)               400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 3,459,901
# Trainable params: 271,001
# Non-trainable params: 3,188,900
# _________________________________________________________________
# None
# Train on 3519 samples, validate on 881 samples
# Epoch 1/20
#  - 7s - loss: 0.6370 - val_loss: 0.3605
#
# Epoch 00001: val_loss improved from inf to 0.36050, saving model to Models/capsule_net_weights_best.h5
# Epoch 2/20
#  - 5s - loss: 0.4440 - val_loss: 0.3460
#
# Epoch 00002: val_loss improved from 0.36050 to 0.34596, saving model to Models/capsule_net_weights_best.h5
# Epoch 3/20
#  - 4s - loss: 0.3546 - val_loss: 0.4335
#
# Epoch 00003: val_loss did not improve from 0.34596
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/20
#  - 4s - loss: 0.3337 - val_loss: 0.3350
#
# Epoch 00004: val_loss improved from 0.34596 to 0.33504, saving model to Models/capsule_net_weights_best.h5
# Epoch 5/20
#  - 4s - loss: 0.3179 - val_loss: 0.3611
#
# Epoch 00005: val_loss did not improve from 0.33504
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 6/20
#  - 5s - loss: 0.3097 - val_loss: 0.3427
#
# Epoch 00006: val_loss did not improve from 0.33504
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 7/20
#  - 5s - loss: 0.2986 - val_loss: 0.3350
#
# Epoch 00007: val_loss improved from 0.33504 to 0.33502, saving model to Models/capsule_net_weights_best.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 8/20
#  - 5s - loss: 0.2927 - val_loss: 0.3368
#
# Epoch 00008: val_loss did not improve from 0.33502
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 9/20
#  - 5s - loss: 0.2856 - val_loss: 0.3476
#
# Epoch 00009: val_loss did not improve from 0.33502
# Epoch 10/20
#  - 5s - loss: 0.2868 - val_loss: 0.3376
#
# Epoch 00010: val_loss did not improve from 0.33502
# Epoch 11/20
#  - 5s - loss: 0.2869 - val_loss: 0.3386
#
# Epoch 00011: val_loss did not improve from 0.33502
# Epoch 12/20
#  - 5s - loss: 0.2786 - val_loss: 0.3419
#
# Epoch 00012: val_loss did not improve from 0.33502
# Epoch 13/20
#  - 5s - loss: 0.2751 - val_loss: 0.3512
#
# Epoch 00013: val_loss did not improve from 0.33502
# Epoch 14/20
#  - 5s - loss: 0.2762 - val_loss: 0.3672
#
# Epoch 00014: val_loss did not improve from 0.33502
# Epoch 15/20
#  - 5s - loss: 0.2730 - val_loss: 0.3454
#
# Epoch 00015: val_loss did not improve from 0.33502
# Epoch 16/20
#  - 5s - loss: 0.2737 - val_loss: 0.3403
#
# Epoch 00016: val_loss did not improve from 0.33502
# Epoch 17/20
#  - 5s - loss: 0.2630 - val_loss: 0.3486
#
# Epoch 00017: val_loss did not improve from 0.33502
# Epoch 18/20
#  - 5s - loss: 0.2678 - val_loss: 0.3415
#
# Epoch 00018: val_loss did not improve from 0.33502
# Epoch 19/20
#  - 5s - loss: 0.2614 - val_loss: 0.3505
#
# Epoch 00019: val_loss did not improve from 0.33502
# Epoch 20/20
#  - 5s - loss: 0.2574 - val_loss: 0.3591
#
# Epoch 00020: val_loss did not improve from 0.33502
# Optimal F1: 0.3709 at threshold: 0.1526
# Train on 3520 samples, validate on 880 samples
# Epoch 1/20
#  - 7s - loss: 0.6238 - val_loss: 0.4124
#
# Epoch 00001: val_loss improved from inf to 0.41239, saving model to Models/capsule_net_weights_best.h5
# Epoch 2/20
#  - 5s - loss: 0.4306 - val_loss: 0.3723
#
# Epoch 00002: val_loss improved from 0.41239 to 0.37235, saving model to Models/capsule_net_weights_best.h5
# Epoch 3/20
#  - 5s - loss: 0.3584 - val_loss: 0.3539
#
# Epoch 00003: val_loss improved from 0.37235 to 0.35390, saving model to Models/capsule_net_weights_best.h5
# Epoch 4/20
#  - 5s - loss: 0.3360 - val_loss: 0.4344
#
# Epoch 00004: val_loss did not improve from 0.35390
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 5/20
#  - 5s - loss: 0.3235 - val_loss: 0.3609
#
# Epoch 00005: val_loss did not improve from 0.35390
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 6/20
#  - 5s - loss: 0.3102 - val_loss: 0.3384
#
# Epoch 00006: val_loss improved from 0.35390 to 0.33838, saving model to Models/capsule_net_weights_best.h5
# Epoch 7/20
#  - 5s - loss: 0.3016 - val_loss: 0.3419
#
# Epoch 00007: val_loss did not improve from 0.33838
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 8/20
#  - 5s - loss: 0.2939 - val_loss: 0.3491
#
# Epoch 00008: val_loss did not improve from 0.33838
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 9/20
#  - 5s - loss: 0.2884 - val_loss: 0.3440
#
# Epoch 00009: val_loss did not improve from 0.33838
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 10/20
#  - 5s - loss: 0.2852 - val_loss: 0.3379
#
# Epoch 00010: val_loss improved from 0.33838 to 0.33790, saving model to Models/capsule_net_weights_best.h5
# Epoch 11/20
#  - 5s - loss: 0.2832 - val_loss: 0.3450
#
# Epoch 00011: val_loss did not improve from 0.33790
# Epoch 12/20
#  - 5s - loss: 0.2799 - val_loss: 0.3455
#
# Epoch 00012: val_loss did not improve from 0.33790
# Epoch 13/20
#  - 5s - loss: 0.2738 - val_loss: 0.3478
#
# Epoch 00013: val_loss did not improve from 0.33790
# Epoch 14/20
#  - 5s - loss: 0.2753 - val_loss: 0.3511
#
# Epoch 00014: val_loss did not improve from 0.33790
# Epoch 15/20
#  - 5s - loss: 0.2690 - val_loss: 0.3612
#
# Epoch 00015: val_loss did not improve from 0.33790
# Epoch 16/20
#  - 5s - loss: 0.2644 - val_loss: 0.3500
#
# Epoch 00016: val_loss did not improve from 0.33790
# Epoch 17/20
#  - 5s - loss: 0.2614 - val_loss: 0.3660
#
# Epoch 00017: val_loss did not improve from 0.33790
# Epoch 18/20
#  - 5s - loss: 0.2649 - val_loss: 0.3588
#
# Epoch 00018: val_loss did not improve from 0.33790
# Epoch 19/20
#  - 5s - loss: 0.2568 - val_loss: 0.3714
#
# Epoch 00019: val_loss did not improve from 0.33790
# Epoch 20/20
#  - 5s - loss: 0.2504 - val_loss: 0.3721
#
# Epoch 00020: val_loss did not improve from 0.33790
# Optimal F1: 0.3750 at threshold: 0.1483
# Train on 3520 samples, validate on 880 samples
# Epoch 1/20
#  - 7s - loss: 0.6473 - val_loss: 0.6028
#
# Epoch 00001: val_loss improved from inf to 0.60284, saving model to Models/capsule_net_weights_best.h5
# Epoch 2/20
#  - 5s - loss: 0.4506 - val_loss: 0.4078
#
# Epoch 00002: val_loss improved from 0.60284 to 0.40775, saving model to Models/capsule_net_weights_best.h5
# Epoch 3/20
#  - 5s - loss: 0.3716 - val_loss: 0.3681
#
# Epoch 00003: val_loss improved from 0.40775 to 0.36812, saving model to Models/capsule_net_weights_best.h5
# Epoch 4/20
#  - 5s - loss: 0.3410 - val_loss: 0.3462
#
# Epoch 00004: val_loss improved from 0.36812 to 0.34615, saving model to Models/capsule_net_weights_best.h5
# Epoch 5/20
#  - 5s - loss: 0.3288 - val_loss: 0.4228
#
# Epoch 00005: val_loss did not improve from 0.34615
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 6/20
#  - 5s - loss: 0.3098 - val_loss: 0.3766
#
# Epoch 00006: val_loss did not improve from 0.34615
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 7/20
#  - 5s - loss: 0.3031 - val_loss: 0.3706
#
# Epoch 00007: val_loss did not improve from 0.34615
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 8/20
#  - 5s - loss: 0.2958 - val_loss: 0.3532
#
# Epoch 00008: val_loss did not improve from 0.34615
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 9/20
#  - 5s - loss: 0.2891 - val_loss: 0.3477
#
# Epoch 00009: val_loss did not improve from 0.34615
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 10/20
#  - 5s - loss: 0.2827 - val_loss: 0.3445
#
# Epoch 00010: val_loss improved from 0.34615 to 0.34451, saving model to Models/capsule_net_weights_best.h5
# Epoch 11/20
#  - 5s - loss: 0.2821 - val_loss: 0.3423
#
# Epoch 00011: val_loss improved from 0.34451 to 0.34227, saving model to Models/capsule_net_weights_best.h5
# Epoch 12/20
#  - 5s - loss: 0.2845 - val_loss: 0.3472
#
# Epoch 00012: val_loss did not improve from 0.34227
# Epoch 13/20
#  - 5s - loss: 0.2743 - val_loss: 0.3467
#
# Epoch 00013: val_loss did not improve from 0.34227
# Epoch 14/20
#  - 5s - loss: 0.2773 - val_loss: 0.3462
#
# Epoch 00014: val_loss did not improve from 0.34227
# Epoch 15/20
#  - 5s - loss: 0.2717 - val_loss: 0.3448
#
# Epoch 00015: val_loss did not improve from 0.34227
# Epoch 16/20
#  - 5s - loss: 0.2664 - val_loss: 0.3502
#
# Epoch 00016: val_loss did not improve from 0.34227
# Epoch 17/20
#  - 5s - loss: 0.2666 - val_loss: 0.3640
#
# Epoch 00017: val_loss did not improve from 0.34227
# Epoch 18/20
#  - 5s - loss: 0.2635 - val_loss: 0.3476
#
# Epoch 00018: val_loss did not improve from 0.34227
# Epoch 19/20
#  - 5s - loss: 0.2629 - val_loss: 0.3530
#
# Epoch 00019: val_loss did not improve from 0.34227
# Epoch 20/20
#  - 5s - loss: 0.2603 - val_loss: 0.3609
#
# Epoch 00020: val_loss did not improve from 0.34227
# Optimal F1: 0.3615 at threshold: 0.1628
# Train on 3520 samples, validate on 880 samples
# Epoch 1/20
#  - 7s - loss: 0.6354 - val_loss: 0.4322
#
# Epoch 00001: val_loss improved from inf to 0.43219, saving model to Models/capsule_net_weights_best.h5
# Epoch 2/20
#  - 5s - loss: 0.4456 - val_loss: 0.3974
#
# Epoch 00002: val_loss improved from 0.43219 to 0.39737, saving model to Models/capsule_net_weights_best.h5
# Epoch 3/20
#  - 5s - loss: 0.3850 - val_loss: 0.3723
#
# Epoch 00003: val_loss improved from 0.39737 to 0.37230, saving model to Models/capsule_net_weights_best.h5
# Epoch 4/20
#  - 5s - loss: 0.3528 - val_loss: 0.3412
#
# Epoch 00004: val_loss improved from 0.37230 to 0.34123, saving model to Models/capsule_net_weights_best.h5
# Epoch 5/20
#  - 5s - loss: 0.3446 - val_loss: 0.3380
#
# Epoch 00005: val_loss improved from 0.34123 to 0.33804, saving model to Models/capsule_net_weights_best.h5
# Epoch 6/20
#  - 5s - loss: 0.3312 - val_loss: 0.3263
#
# Epoch 00006: val_loss improved from 0.33804 to 0.32631, saving model to Models/capsule_net_weights_best.h5
# Epoch 7/20
#  - 5s - loss: 0.3234 - val_loss: 0.3770
#
# Epoch 00007: val_loss did not improve from 0.32631
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 8/20
#  - 5s - loss: 0.3210 - val_loss: 0.3453
#
# Epoch 00008: val_loss did not improve from 0.32631
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 9/20
#  - 5s - loss: 0.3036 - val_loss: 0.3351
#
# Epoch 00009: val_loss did not improve from 0.32631
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 10/20
#  - 5s - loss: 0.2956 - val_loss: 0.3392
#
# Epoch 00010: val_loss did not improve from 0.32631
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 11/20
#  - 5s - loss: 0.2857 - val_loss: 0.3409
#
# Epoch 00011: val_loss did not improve from 0.32631
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 12/20
#  - 5s - loss: 0.2836 - val_loss: 0.3427
#
# Epoch 00012: val_loss did not improve from 0.32631
# Epoch 13/20
#  - 5s - loss: 0.2801 - val_loss: 0.3383
#
# Epoch 00013: val_loss did not improve from 0.32631
# Epoch 14/20
#  - 5s - loss: 0.2741 - val_loss: 0.3468
#
# Epoch 00014: val_loss did not improve from 0.32631
# Epoch 15/20
#  - 5s - loss: 0.2704 - val_loss: 0.3511
#
# Epoch 00015: val_loss did not improve from 0.32631
# Epoch 16/20
#  - 5s - loss: 0.2697 - val_loss: 0.3390
#
# Epoch 00016: val_loss did not improve from 0.32631
# Epoch 17/20
#  - 5s - loss: 0.2668 - val_loss: 0.3455
#
# Epoch 00017: val_loss did not improve from 0.32631
# Epoch 18/20
#  - 5s - loss: 0.2663 - val_loss: 0.3459
#
# Epoch 00018: val_loss did not improve from 0.32631
# Epoch 19/20
#  - 5s - loss: 0.2675 - val_loss: 0.3457
#
# Epoch 00019: val_loss did not improve from 0.32631
# Epoch 20/20
#  - 5s - loss: 0.2617 - val_loss: 0.3461
#
# Epoch 00020: val_loss did not improve from 0.32631
# Optimal F1: 0.4000 at threshold: 0.1945
# Train on 3521 samples, validate on 879 samples
# Epoch 1/20
#  - 7s - loss: 0.6323 - val_loss: 0.4431
#
# Epoch 00001: val_loss improved from inf to 0.44308, saving model to Models/capsule_net_weights_best.h5
# Epoch 2/20
#  - 5s - loss: 0.4580 - val_loss: 0.3592
#
# Epoch 00002: val_loss improved from 0.44308 to 0.35919, saving model to Models/capsule_net_weights_best.h5
# Epoch 3/20
#  - 5s - loss: 0.3764 - val_loss: 0.3675
#
# Epoch 00003: val_loss did not improve from 0.35919
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/20
#  - 5s - loss: 0.3422 - val_loss: 0.3472
#
# Epoch 00004: val_loss improved from 0.35919 to 0.34722, saving model to Models/capsule_net_weights_best.h5
# Epoch 5/20
#  - 5s - loss: 0.3282 - val_loss: 0.3374
#
# Epoch 00005: val_loss improved from 0.34722 to 0.33736, saving model to Models/capsule_net_weights_best.h5
# Epoch 6/20
#  - 5s - loss: 0.3163 - val_loss: 0.3599
#
# Epoch 00006: val_loss did not improve from 0.33736
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 7/20
#  - 5s - loss: 0.3043 - val_loss: 0.3899
#
# Epoch 00007: val_loss did not improve from 0.33736
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 8/20
#  - 5s - loss: 0.2971 - val_loss: 0.3495
#
# Epoch 00008: val_loss did not improve from 0.33736
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 9/20
#  - 5s - loss: 0.2952 - val_loss: 0.3352
#
# Epoch 00009: val_loss improved from 0.33736 to 0.33524, saving model to Models/capsule_net_weights_best.h5
# Epoch 10/20
#  - 5s - loss: 0.2863 - val_loss: 0.3314
#
# Epoch 00010: val_loss improved from 0.33524 to 0.33143, saving model to Models/capsule_net_weights_best.h5
# Epoch 11/20
#  - 5s - loss: 0.2831 - val_loss: 0.3402
#
# Epoch 00011: val_loss did not improve from 0.33143
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 12/20
#  - 5s - loss: 0.2787 - val_loss: 0.3394
#
# Epoch 00012: val_loss did not improve from 0.33143
# Epoch 13/20
#  - 5s - loss: 0.2819 - val_loss: 0.3375
#
# Epoch 00013: val_loss did not improve from 0.33143
# Epoch 14/20
#  - 5s - loss: 0.2746 - val_loss: 0.3399
#
# Epoch 00014: val_loss did not improve from 0.33143
# Epoch 15/20
#  - 5s - loss: 0.2717 - val_loss: 0.3412
#
# Epoch 00015: val_loss did not improve from 0.33143
# Epoch 16/20
#  - 5s - loss: 0.2707 - val_loss: 0.3411
#
# Epoch 00016: val_loss did not improve from 0.33143
# Epoch 17/20
#  - 5s - loss: 0.2646 - val_loss: 0.3397
#
# Epoch 00017: val_loss did not improve from 0.33143
# Epoch 18/20
#  - 5s - loss: 0.2634 - val_loss: 0.3507
#
# Epoch 00018: val_loss did not improve from 0.33143
# Epoch 19/20
#  - 5s - loss: 0.2557 - val_loss: 0.3615
#
# Epoch 00019: val_loss did not improve from 0.33143
# Epoch 20/20
#  - 5s - loss: 0.2572 - val_loss: 0.3658
#
# Epoch 00020: val_loss did not improve from 0.33143
# Optimal F1: 0.4071 at threshold: 0.1575

# %% [markdown]
# Converting the predictions for integer.

# %%
y_test = y_test.reshape((-1, 1))
pred_test_y = (y_test>np.mean(bestscore)).astype(int)
test['predictions'] = le.inverse_transform(pred_test_y)
# Out:
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/sklearn/preprocessing/label.py:273: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(test["subtask_b"], test['predictions']).ravel()
(tn, fp, fn, tp)
# Out:
# (168, 45, 5, 22)

# %%
from visualization.confusion_matrix_pretty_print import plot_confusion_matrix_from_data

columns = []
annot = True
cmap = 'Oranges'
fmt = '.2f'
lw = 0.5
cbar = False
show_null_values = 2
pred_val_axis = 'y'
# size::
fz = 12;
figsize = [9, 9];
if len(y_test) > 10:
    fz = 9;
    figsize = [14, 14];
plot_confusion_matrix_from_data(test["subtask_b"], test['predictions'], columns,
                                    annot, cmap, fmt, fz, lw, cbar, figsize, show_null_values, pred_val_axis)

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test["subtask_b"], test['predictions'])
# Out:
# 0.7916666666666666
