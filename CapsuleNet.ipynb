# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn import metrics

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import *
from keras.models import *
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.initializers import *
from keras.optimizers import *
import keras.backend as K
from keras.callbacks import *
import tensorflow as tf
import os
import time
import gc
import re
from unidecode import unidecode

# %%
train = pd.read_csv("Data/offenseval-training-v1.tsv", sep='\t')
test = pd.read_csv("Data/test.tsv")
print("Train shape : ", train.shape)
print("Test shape : ", test.shape)
# Out:
# Train shape :  (13240, 5)
# Test shape :  (860, 3)

# %%
train["tweet"] = train["tweet"].str.lower()
test["tweet"] = test["tweet"].str.lower()

# %%
puncts = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£', 
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', 
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', 
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', 
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√', ]

def clean_text(x):

    x = str(x)
    for punct in puncts:
        x = x.replace(punct, f' {punct} ')
    return x


train["tweet"] = train["tweet"].apply(lambda x: clean_text(x))
test["tweet"] = test["tweet"].apply(lambda x: clean_text(x))

# %%
## some config values 
embed_size = 300 # how big is each word vector
max_features = None # how many unique words to use (i.e num rows in embedding vector)
maxlen = 72 # max number of words in a question to use #99.99%

## fill up the missing values
X = train["tweet"].fillna("_na_").values
X_test = test["tweet"].fillna("_na_").values

## Tokenize the sentences
tokenizer = Tokenizer(num_words=max_features, filters='')
tokenizer.fit_on_texts(list(X))

X = tokenizer.texts_to_sequences(X)
X_test = tokenizer.texts_to_sequences(X_test)

## Pad the sentences 
X = pad_sequences(X, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

## Get the target values
Y = train['subtask_a'].values

# %%
word_index = tokenizer.word_index
max_features = len(word_index)+1
def load_glove(word_index):
    EMBEDDING_FILE = '/data/glove/glove.840B.300d.txt'
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if o.split(" ")[0] in word_index)

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    embedding_matrix = np.random.normal(emb_mean, emb_std, (max_features, embed_size))
    for word, i in word_index.items():
        if i >= max_features: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector
            
    return embedding_matrix 
    
def load_fasttext(word_index):    
    EMBEDDING_FILE = '/data/fasttext/crawl-300d-2M-subword.vec'
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if len(o)>100 and o.split(" ")[0] in word_index )

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    embedding_matrix = np.random.normal(emb_mean, emb_std, (max_features, embed_size))
    for word, i in word_index.items():
        if i >= max_features: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector

    return embedding_matrix

# %%
embedding_matrix = load_glove(word_index)

# %%
def squash(x, axis=-1):
    s_squared_norm = K.sum(K.square(x), axis, keepdims=True)
    scale = K.sqrt(s_squared_norm + K.epsilon())
    return x / scale

# %%
class Capsule(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, kernel_size=(9, 1), share_weights=True,
                 activation='default', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.kernel_size = kernel_size
        self.share_weights = share_weights
        if activation == 'default':
            self.activation = squash
        else:
            self.activation = Activation(activation)

    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     # shape=self.kernel_size,
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
            
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))
        # final u_hat_vecs.shape = [None, num_capsule, input_num_capsule, dim_capsule]

        b = K.zeros_like(u_hat_vecs[:, :, :, 0])  # shape = [None, num_capsule, input_num_capsule]
        for i in range(self.routings):
            b = K.permute_dimensions(b, (0, 2, 1))  # shape = [None, input_num_capsule, num_capsule]
            c = K.softmax(b)
            c = K.permute_dimensions(c, (0, 2, 1))
            b = K.permute_dimensions(b, (0, 2, 1))
            outputs = self.activation(K.batch_dot(c, u_hat_vecs, [2, 2]))
            if i < self.routings - 1:
                b = K.batch_dot(outputs, u_hat_vecs, [2, 3])

        return outputs

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
def capsule():
    K.clear_session()       
    inp = Input(shape=(maxlen,))
    x = Embedding(max_features, embed_size, weights=[embedding_matrix], trainable=False)(inp)
    x = SpatialDropout1D(rate=0.2)(x)
    x = Bidirectional(GRU(100, return_sequences=True, 
                                kernel_initializer=glorot_normal(seed=12300), recurrent_initializer=orthogonal(gain=1.0, seed=10000)))(x)

    x = Capsule(num_capsule=10, dim_capsule=10, routings=4, share_weights=True)(x)
    x = Flatten()(x)

    x = Dense(100, activation="relu", kernel_initializer=glorot_normal(seed=12300))(x)
    x = Dropout(0.12)(x)
    x = BatchNormalization()(x)

    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer=Adam(),)
    return model

# %%
def f1_smart(y_true, y_pred):
    args = np.argsort(y_pred)
    tp = y_true.sum()
    fs = (tp - np.cumsum(y_true[args[:-1]])) / np.arange(y_true.shape[0] + tp - 1, tp, -1)
    res_idx = np.argmax(fs)
    return 2 * fs[res_idx], (y_pred[args[res_idx]] + y_pred[args[res_idx + 1]]) / 2

# %%
kfold = StratifiedKFold(n_splits=5, random_state=10, shuffle=True)
bestscore = []
y_test = np.zeros((X_test.shape[0], ))
for i, (train_index, valid_index) in enumerate(kfold.split(X, Y)):
    X_train, X_val, Y_train, Y_val = X[train_index], X[valid_index], Y[train_index], Y[valid_index]
    filepath="weights_best.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=2, save_best_only=True, mode='min')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.6, patience=1, min_lr=0.0001, verbose=2)
    earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=2, mode='auto')
    callbacks = [checkpoint, reduce_lr]
    model = capsule()
    if i == 0:print(model.summary()) 
    model.fit(X_train, Y_train, batch_size=64, epochs=20, validation_data=(X_val, Y_val), verbose=2, callbacks=callbacks, 
             )
    model.load_weights(filepath)
    y_pred = model.predict([X_val], batch_size=64, verbose=2)
    y_test += np.squeeze(model.predict([X_test], batch_size=64, verbose=2))/5
    f1, threshold = f1_smart(np.squeeze(Y_val), np.squeeze(y_pred))
    print('Optimal F1: {:.4f} at threshold: {:.4f}'.format(f1, threshold))
    bestscore.append(threshold)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 72)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 72, 300)           6036000
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 72, 300)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 72, 200)           240600
# _________________________________________________________________
# capsule_1 (Capsule)          (None, 10, 10)            20000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100)               400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 6,307,201
# Trainable params: 271,001
# Non-trainable params: 6,036,200
# _________________________________________________________________
# None
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/6
#  - 9s - loss: 0.7322 - val_loss: 0.6169
#
# Epoch 00001: val_loss improved from inf to 0.61691, saving model to weights_best.h5
# Epoch 2/6
#  - 8s - loss: 0.6026 - val_loss: 0.5142
#
# Epoch 00002: val_loss improved from 0.61691 to 0.51422, saving model to weights_best.h5
# Epoch 3/6
#  - 8s - loss: 0.5228 - val_loss: 0.4653
#
# Epoch 00003: val_loss improved from 0.51422 to 0.46534, saving model to weights_best.h5
# Epoch 4/6
#  - 8s - loss: 0.4855 - val_loss: 0.4584
#
# Epoch 00004: val_loss improved from 0.46534 to 0.45836, saving model to weights_best.h5
# Epoch 5/6
#  - 8s - loss: 0.4651 - val_loss: 0.4530
#
# Epoch 00005: val_loss improved from 0.45836 to 0.45299, saving model to weights_best.h5
# Epoch 6/6
#  - 8s - loss: 0.4554 - val_loss: 0.4486
#
# Epoch 00006: val_loss improved from 0.45299 to 0.44855, saving model to weights_best.h5
# Optimal F1: 0.6867 at threshold: 0.2999
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/6
#  - 9s - loss: 0.7404 - val_loss: 0.7346
#
# Epoch 00001: val_loss improved from inf to 0.73458, saving model to weights_best.h5
# Epoch 2/6
#  - 8s - loss: 0.6051 - val_loss: 0.5328
#
# Epoch 00002: val_loss improved from 0.73458 to 0.53276, saving model to weights_best.h5
# Epoch 3/6
#  - 8s - loss: 0.5252 - val_loss: 0.4990
#
# Epoch 00003: val_loss improved from 0.53276 to 0.49896, saving model to weights_best.h5
# Epoch 4/6
#  - 8s - loss: 0.4782 - val_loss: 0.4826
#
# Epoch 00004: val_loss improved from 0.49896 to 0.48261, saving model to weights_best.h5
# Epoch 5/6
#  - 8s - loss: 0.4674 - val_loss: 0.5086
#
# Epoch 00005: val_loss did not improve from 0.48261
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 6/6
#  - 8s - loss: 0.4539 - val_loss: 0.4939
#
# Epoch 00006: val_loss did not improve from 0.48261
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Optimal F1: 0.6734 at threshold: 0.2658
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/6
#  - 9s - loss: 0.7213 - val_loss: 0.6041
#
# Epoch 00001: val_loss improved from inf to 0.60413, saving model to weights_best.h5
# Epoch 2/6
#  - 8s - loss: 0.5940 - val_loss: 0.5054
#
# Epoch 00002: val_loss improved from 0.60413 to 0.50540, saving model to weights_best.h5
# Epoch 3/6
#  - 8s - loss: 0.5150 - val_loss: 0.4820
#
# Epoch 00003: val_loss improved from 0.50540 to 0.48205, saving model to weights_best.h5
# Epoch 4/6
#  - 8s - loss: 0.4775 - val_loss: 0.4573
#
# Epoch 00004: val_loss improved from 0.48205 to 0.45730, saving model to weights_best.h5
# Epoch 5/6
#  - 8s - loss: 0.4606 - val_loss: 0.5303
#
# Epoch 00005: val_loss did not improve from 0.45730
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 6/6
#  - 8s - loss: 0.4435 - val_loss: 0.4700
#
# Epoch 00006: val_loss did not improve from 0.45730
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Optimal F1: 0.6818 at threshold: 0.2875
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/6
#  - 9s - loss: 0.7409 - val_loss: 0.6733
#
# Epoch 00001: val_loss improved from inf to 0.67335, saving model to weights_best.h5
# Epoch 2/6
#  - 8s - loss: 0.6192 - val_loss: 0.5113
#
# Epoch 00002: val_loss improved from 0.67335 to 0.51131, saving model to weights_best.h5
# Epoch 3/6
#  - 8s - loss: 0.5285 - val_loss: 0.5143
#
# Epoch 00003: val_loss did not improve from 0.51131
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/6
#  - 8s - loss: 0.4909 - val_loss: 0.4686
#
# Epoch 00004: val_loss improved from 0.51131 to 0.46857, saving model to weights_best.h5
# Epoch 5/6
#  - 8s - loss: 0.4764 - val_loss: 0.4648
#
# Epoch 00005: val_loss improved from 0.46857 to 0.46476, saving model to weights_best.h5
# Epoch 6/6
#  - 8s - loss: 0.4595 - val_loss: 0.4612
#
# Epoch 00006: val_loss improved from 0.46476 to 0.46121, saving model to weights_best.h5
# Optimal F1: 0.6891 at threshold: 0.2928
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/6
#  - 9s - loss: 0.7276 - val_loss: 0.5927
#
# Epoch 00001: val_loss improved from inf to 0.59274, saving model to weights_best.h5
# Epoch 2/6
#  - 8s - loss: 0.5933 - val_loss: 0.5128
#
# Epoch 00002: val_loss improved from 0.59274 to 0.51284, saving model to weights_best.h5
# Epoch 3/6
#  - 8s - loss: 0.5142 - val_loss: 0.4831
#
# Epoch 00003: val_loss improved from 0.51284 to 0.48311, saving model to weights_best.h5
# Epoch 4/6
#  - 8s - loss: 0.4741 - val_loss: 0.4645
#
# Epoch 00004: val_loss improved from 0.48311 to 0.46445, saving model to weights_best.h5
# Epoch 5/6
#  - 8s - loss: 0.4604 - val_loss: 0.5308
#
# Epoch 00005: val_loss did not improve from 0.46445
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 6/6
#  - 8s - loss: 0.4490 - val_loss: 0.4493
#
# Epoch 00006: val_loss improved from 0.46445 to 0.44934, saving model to weights_best.h5
# Optimal F1: 0.6925 at threshold: 0.2396

# %%
y_test = y_test.reshape((-1, 1))
pred_test_y = (y_test>np.mean(bestscore)).astype(int)
test['predictions'] = pred_test_y

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(test["subtask_a"], test['predictions']).ravel()
(tn, fp, fn, tp)
# Out:
# (527, 93, 64, 176)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test["subtask_a"], test['predictions'])
# Out:
# 0.8174418604651162
