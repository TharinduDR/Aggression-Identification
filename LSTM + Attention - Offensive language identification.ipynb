# %% [markdown]
# ## Offensive Language Identification
#
# This is the task 'a' in Task 6: OffensEval: Identifying and Categorizing Offensive Language in Social Media in SemEval 2019. We have explored how a casule network can be used in Offensive language identification.

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn import metrics

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import *
from keras.models import *
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.initializers import *
from keras.optimizers import *
import keras.backend as K
from keras.callbacks import *
import tensorflow as tf
import os
import time
import gc
import re
from unidecode import unidecode
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Loading the training and testing files

# %%
train = pd.read_csv("Data/training/offenseval-training-v1.tsv", sep='\t')

test_tweets = pd.read_csv("Data/testing/testset-taska.tsv", sep='\t')
test_labels = pd.read_csv("Data/testing/labels-test-a.csv", header=-1, names = ["id", "subtask_a"])

test = pd.merge(test_tweets, test_labels, on=['id','id'])
print("Train shape : ", train.shape)
print("Test shape : ", test.shape)
# Out:
# Train shape :  (13240, 5)
# Test shape :  (860, 3)

# %% [markdown]
# Changing case of the tweets to lower case, since the embedding model only has lower case words

# %%
train["tweet"] = train["tweet"].str.lower()
test["tweet"] = test["tweet"].str.lower()

# %% [markdown]
# cleaning the puncutation marks

# %%
puncts = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£', 
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', 
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', 
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', 
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√', ]

def clean_text(x):

    x = str(x)
    for punct in puncts:
        x = x.replace(punct, f' {punct} ')
    return x


train["tweet"] = train["tweet"].apply(lambda x: clean_text(x))
test["tweet"] = test["tweet"].apply(lambda x: clean_text(x))

# %%
## some config values 
embed_size = 300 # how big is each word vector
max_features = None # how many unique words to use (i.e num rows in embedding vector)
maxlen = 72 # max number of words in a question to use #99.99%

## fill up the missing values
X = train["tweet"].fillna("_na_").values
X_test = test["tweet"].fillna("_na_").values

## Tokenize the sentences
tokenizer = Tokenizer(num_words=max_features, filters='')
tokenizer.fit_on_texts(list(X))

X = tokenizer.texts_to_sequences(X)
X_test = tokenizer.texts_to_sequences(X_test)

## Pad the sentences 
X = pad_sequences(X, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

## Get the target values
Y = train['subtask_a'].values
Y
# Out:
# array(['OFF', 'OFF', 'NOT', ..., 'OFF', 'OFF', 'NOT'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(Y)
encoded_Y = le.transform(Y)
encoded_Y
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %% [markdown]
# Building the Embedding matrix

# %%
word_index = tokenizer.word_index
max_features = len(word_index)+1
def load_glove(word_index):
    EMBEDDING_FILE = '/data/glove/glove.840B.300d.txt'
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if o.split(" ")[0] in word_index)

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    embedding_matrix = np.random.normal(emb_mean, emb_std, (max_features, embed_size))
    for word, i in word_index.items():
        if i >= max_features: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector
            
    return embedding_matrix 
    
def load_fasttext(word_index):    
    EMBEDDING_FILE = '/data/fasttext/crawl-300d-2M-subword.vec'
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if len(o)>100 and o.split(" ")[0] in word_index )

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    embedding_matrix = np.random.normal(emb_mean, emb_std, (max_features, embed_size))
    for word, i in word_index.items():
        if i >= max_features: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector

    return embedding_matrix

# %% [markdown]
# Only Glove vectors have been used in embedding matrix. Can explore it further in future

# %%
embedding_matrix = load_glove(word_index)

# %% [markdown]
# Definning the Capsule Layer in Keras

# %%
# https://www.kaggle.com/qqgeogor/keras-lstm-attention-glove840b-lb-0-043
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True
        
    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %% [markdown]
# Capsule Layer with a Bi directional GRU. Architecture found in text classification project.

# %%
def lstm_attention():
    K.clear_session()       
    inp = Input(shape=(maxlen,))
    x = Embedding(max_features, embed_size, weights=[embedding_matrix], trainable=False)(inp)
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    x = Bidirectional(LSTM(64,return_sequences=True))(x)
    x = Attention(maxlen)(x)
    x = Dense(256, activation="relu")(x)
    # x = Dropout(0.25)(x)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
def f1_smart(y_true, y_pred):
    args = np.argsort(y_pred)
    tp = y_true.sum()
    fs = (tp - np.cumsum(y_true[args[:-1]])) / np.arange(y_true.shape[0] + tp - 1, tp, -1)
    res_idx = np.argmax(fs)
    return 2 * fs[res_idx], (y_pred[args[res_idx]] + y_pred[args[res_idx + 1]]) / 2

# %% [markdown]
# Training with early stopping and reducing learning rate on plateu. In each fold values for the test set is also predicted, And after the process, predicted values for the test file would be mean from each fold

# %%
kfold = StratifiedKFold(n_splits=5, random_state=10, shuffle=True)
bestscore = []
y_test = np.zeros((X_test.shape[0], ))
for i, (train_index, valid_index) in enumerate(kfold.split(X, encoded_Y)):
    X_train, X_val, Y_train, Y_val = X[train_index], X[valid_index], encoded_Y[train_index], encoded_Y[valid_index]
    filepath="Models/lstm_attention_weights_best.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=2, save_best_only=True, mode='min')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.6, patience=1, min_lr=0.0001, verbose=2)
    earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=2, mode='auto')
    callbacks = [checkpoint, reduce_lr]
    model = lstm_attention()
    if i == 0:print(model.summary()) 
    model.fit(X_train, Y_train, batch_size=64, epochs=20, validation_data=(X_val, Y_val), verbose=2, callbacks=callbacks, 
             )
    model.load_weights(filepath)
    y_pred = model.predict([X_val], batch_size=64, verbose=2)
    y_test += np.squeeze(model.predict([X_test], batch_size=64, verbose=2))/5
    f1, threshold = f1_smart(np.squeeze(Y_val), np.squeeze(y_pred))
    print('Optimal F1: {:.4f} at threshold: {:.4f}'.format(f1, threshold))
    bestscore.append(threshold)
# Out:
# WARNING:tensorflow:From /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 72)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 72, 300)           6036600
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 72, 128)           186880
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 72, 128)           98816
# _________________________________________________________________
# attention_1 (Attention)      (None, 128)               200
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 6,355,777
# Trainable params: 319,177
# Non-trainable params: 6,036,600
# _________________________________________________________________
# None
# WARNING:tensorflow:From /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 34s - loss: 0.5343 - acc: 0.7313 - val_loss: 0.4659 - val_acc: 0.7787
#
# Epoch 00001: val_loss improved from inf to 0.46592, saving model to Models/lstm_attention_weights_best.h5
# Epoch 2/20
#  - 31s - loss: 0.4502 - acc: 0.7911 - val_loss: 0.4447 - val_acc: 0.7980
#
# Epoch 00002: val_loss improved from 0.46592 to 0.44466, saving model to Models/lstm_attention_weights_best.h5
# Epoch 3/20
#  - 32s - loss: 0.4312 - acc: 0.8011 - val_loss: 0.4435 - val_acc: 0.8002
#
# Epoch 00003: val_loss improved from 0.44466 to 0.44348, saving model to Models/lstm_attention_weights_best.h5
# Epoch 4/20
#  - 31s - loss: 0.4159 - acc: 0.8119 - val_loss: 0.4439 - val_acc: 0.7942
#
# Epoch 00004: val_loss did not improve from 0.44348
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 5/20
#  - 31s - loss: 0.3856 - acc: 0.8259 - val_loss: 0.4632 - val_acc: 0.7919
#
# Epoch 00005: val_loss did not improve from 0.44348
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 6/20
#  - 32s - loss: 0.3576 - acc: 0.8409 - val_loss: 0.4803 - val_acc: 0.7897
#
# Epoch 00006: val_loss did not improve from 0.44348
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 7/20
#  - 32s - loss: 0.3267 - acc: 0.8586 - val_loss: 0.4909 - val_acc: 0.7810
#
# Epoch 00007: val_loss did not improve from 0.44348
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 8/20
#  - 33s - loss: 0.3005 - acc: 0.8740 - val_loss: 0.5226 - val_acc: 0.7779
#
# Epoch 00008: val_loss did not improve from 0.44348
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 9/20
#  - 26s - loss: 0.2806 - acc: 0.8835 - val_loss: 0.5358 - val_acc: 0.7798
#
# Epoch 00009: val_loss did not improve from 0.44348
# Epoch 10/20
#  - 31s - loss: 0.2671 - acc: 0.8916 - val_loss: 0.5746 - val_acc: 0.7802
#
# Epoch 00010: val_loss did not improve from 0.44348
# Epoch 11/20
#  - 32s - loss: 0.2535 - acc: 0.8999 - val_loss: 0.5827 - val_acc: 0.7787
#
# Epoch 00011: val_loss did not improve from 0.44348
# Epoch 12/20
#  - 32s - loss: 0.2370 - acc: 0.9072 - val_loss: 0.6046 - val_acc: 0.7715
#
# Epoch 00012: val_loss did not improve from 0.44348
# Epoch 13/20
#  - 32s - loss: 0.2232 - acc: 0.9134 - val_loss: 0.6255 - val_acc: 0.7738
#
# Epoch 00013: val_loss did not improve from 0.44348
# Epoch 14/20
#  - 32s - loss: 0.2076 - acc: 0.9229 - val_loss: 0.6701 - val_acc: 0.7719
#
# Epoch 00014: val_loss did not improve from 0.44348
# Epoch 15/20
#  - 32s - loss: 0.1952 - acc: 0.9280 - val_loss: 0.7001 - val_acc: 0.7715
#
# Epoch 00015: val_loss did not improve from 0.44348
# Epoch 16/20
#  - 32s - loss: 0.1811 - acc: 0.9348 - val_loss: 0.7218 - val_acc: 0.7651
#
# Epoch 00016: val_loss did not improve from 0.44348
# Epoch 17/20
#  - 32s - loss: 0.1679 - acc: 0.9403 - val_loss: 0.7605 - val_acc: 0.7670
#
# Epoch 00017: val_loss did not improve from 0.44348
# Epoch 18/20
#  - 32s - loss: 0.1574 - acc: 0.9447 - val_loss: 0.7756 - val_acc: 0.7640
#
# Epoch 00018: val_loss did not improve from 0.44348
# Epoch 19/20
#  - 24s - loss: 0.1483 - acc: 0.9489 - val_loss: 0.8273 - val_acc: 0.7651
#
# Epoch 00019: val_loss did not improve from 0.44348
# Epoch 20/20
#  - 13s - loss: 0.1360 - acc: 0.9546 - val_loss: 0.8826 - val_acc: 0.7640
#
# Epoch 00020: val_loss did not improve from 0.44348
# Optimal F1: 0.7009 at threshold: 0.2818
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 14s - loss: 0.5224 - acc: 0.7398 - val_loss: 0.4780 - val_acc: 0.7681
#
# Epoch 00001: val_loss improved from inf to 0.47805, saving model to Models/lstm_attention_weights_best.h5
# Epoch 2/20
#  - 13s - loss: 0.4402 - acc: 0.8018 - val_loss: 0.4655 - val_acc: 0.7745
#
# Epoch 00002: val_loss improved from 0.47805 to 0.46550, saving model to Models/lstm_attention_weights_best.h5
# Epoch 3/20
#  - 13s - loss: 0.4203 - acc: 0.8104 - val_loss: 0.4558 - val_acc: 0.7836
#
# Epoch 00003: val_loss improved from 0.46550 to 0.45578, saving model to Models/lstm_attention_weights_best.h5
# Epoch 4/20
#  - 13s - loss: 0.4043 - acc: 0.8167 - val_loss: 0.4647 - val_acc: 0.7825
#
# Epoch 00004: val_loss did not improve from 0.45578
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 5/20
#  - 13s - loss: 0.3795 - acc: 0.8309 - val_loss: 0.4716 - val_acc: 0.7813
#
# Epoch 00005: val_loss did not improve from 0.45578
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 6/20
#  - 13s - loss: 0.3512 - acc: 0.8472 - val_loss: 0.5082 - val_acc: 0.7840
#
# Epoch 00006: val_loss did not improve from 0.45578
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 7/20
#  - 13s - loss: 0.3222 - acc: 0.8629 - val_loss: 0.5065 - val_acc: 0.7764
#
# Epoch 00007: val_loss did not improve from 0.45578
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 8/20
#  - 13s - loss: 0.2950 - acc: 0.8793 - val_loss: 0.5198 - val_acc: 0.7704
#
# Epoch 00008: val_loss did not improve from 0.45578
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 9/20
#  - 13s - loss: 0.2757 - acc: 0.8880 - val_loss: 0.5546 - val_acc: 0.7723
#
# Epoch 00009: val_loss did not improve from 0.45578
# Epoch 10/20
#  - 13s - loss: 0.2607 - acc: 0.8974 - val_loss: 0.5679 - val_acc: 0.7727
#
# Epoch 00010: val_loss did not improve from 0.45578
# Epoch 11/20
#  - 13s - loss: 0.2474 - acc: 0.9054 - val_loss: 0.6132 - val_acc: 0.7662
#
# Epoch 00011: val_loss did not improve from 0.45578
# Epoch 12/20
#  - 13s - loss: 0.2335 - acc: 0.9126 - val_loss: 0.6096 - val_acc: 0.7625
#
# Epoch 00012: val_loss did not improve from 0.45578
# Epoch 13/20
#  - 13s - loss: 0.2200 - acc: 0.9200 - val_loss: 0.6491 - val_acc: 0.7655
#
# Epoch 00013: val_loss did not improve from 0.45578
# Epoch 14/20
#  - 13s - loss: 0.2081 - acc: 0.9240 - val_loss: 0.6624 - val_acc: 0.7644
#
# Epoch 00014: val_loss did not improve from 0.45578
# Epoch 15/20
#  - 13s - loss: 0.1935 - acc: 0.9317 - val_loss: 0.7094 - val_acc: 0.7681
#
# Epoch 00015: val_loss did not improve from 0.45578
# Epoch 16/20
#  - 13s - loss: 0.1827 - acc: 0.9365 - val_loss: 0.7004 - val_acc: 0.7644
#
# Epoch 00016: val_loss did not improve from 0.45578
# Epoch 17/20
#  - 13s - loss: 0.1707 - acc: 0.9422 - val_loss: 0.7320 - val_acc: 0.7628
#
# Epoch 00017: val_loss did not improve from 0.45578
# Epoch 18/20
#  - 13s - loss: 0.1569 - acc: 0.9464 - val_loss: 0.7872 - val_acc: 0.7636
#
# Epoch 00018: val_loss did not improve from 0.45578
# Epoch 19/20
#  - 13s - loss: 0.1508 - acc: 0.9511 - val_loss: 0.7975 - val_acc: 0.7587
#
# Epoch 00019: val_loss did not improve from 0.45578
# Epoch 20/20
#  - 13s - loss: 0.1385 - acc: 0.9557 - val_loss: 0.8513 - val_acc: 0.7659
#
# Epoch 00020: val_loss did not improve from 0.45578
# Optimal F1: 0.6819 at threshold: 0.3802
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 14s - loss: 0.5460 - acc: 0.7306 - val_loss: 0.4571 - val_acc: 0.7813
#
# Epoch 00001: val_loss improved from inf to 0.45710, saving model to Models/lstm_attention_weights_best.h5
# Epoch 2/20
#  - 13s - loss: 0.4477 - acc: 0.7930 - val_loss: 0.4507 - val_acc: 0.7863
#
# Epoch 00002: val_loss improved from 0.45710 to 0.45067, saving model to Models/lstm_attention_weights_best.h5
# Epoch 3/20
#  - 13s - loss: 0.4260 - acc: 0.7993 - val_loss: 0.4450 - val_acc: 0.7942
#
# Epoch 00003: val_loss improved from 0.45067 to 0.44503, saving model to Models/lstm_attention_weights_best.h5
# Epoch 4/20
#  - 13s - loss: 0.4120 - acc: 0.8087 - val_loss: 0.4404 - val_acc: 0.7931
#
# Epoch 00004: val_loss improved from 0.44503 to 0.44040, saving model to Models/lstm_attention_weights_best.h5
# Epoch 5/20
#  - 13s - loss: 0.3900 - acc: 0.8214 - val_loss: 0.4614 - val_acc: 0.7847
#
# Epoch 00005: val_loss did not improve from 0.44040
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 6/20
#  - 13s - loss: 0.3532 - acc: 0.8439 - val_loss: 0.4597 - val_acc: 0.7889
#
# Epoch 00006: val_loss did not improve from 0.44040
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 7/20
#  - 13s - loss: 0.3165 - acc: 0.8629 - val_loss: 0.4938 - val_acc: 0.7859
#
# Epoch 00007: val_loss did not improve from 0.44040
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 8/20
#  - 13s - loss: 0.2737 - acc: 0.8873 - val_loss: 0.5226 - val_acc: 0.7768
#
# Epoch 00008: val_loss did not improve from 0.44040
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 9/20
#  - 13s - loss: 0.2395 - acc: 0.9022 - val_loss: 0.5858 - val_acc: 0.7783
#
# Epoch 00009: val_loss did not improve from 0.44040
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 10/20
#  - 13s - loss: 0.2141 - acc: 0.9158 - val_loss: 0.6303 - val_acc: 0.7666
#
# Epoch 00010: val_loss did not improve from 0.44040
# Epoch 11/20
#  - 13s - loss: 0.1961 - acc: 0.9266 - val_loss: 0.6566 - val_acc: 0.7632
#
# Epoch 00011: val_loss did not improve from 0.44040
# Epoch 12/20
#  - 13s - loss: 0.1797 - acc: 0.9338 - val_loss: 0.6898 - val_acc: 0.7583
#
# Epoch 00012: val_loss did not improve from 0.44040
# Epoch 13/20
#  - 13s - loss: 0.1665 - acc: 0.9409 - val_loss: 0.7389 - val_acc: 0.7628
#
# Epoch 00013: val_loss did not improve from 0.44040
# Epoch 14/20
#  - 13s - loss: 0.1541 - acc: 0.9457 - val_loss: 0.7805 - val_acc: 0.7621
#
# Epoch 00014: val_loss did not improve from 0.44040
# Epoch 15/20
#  - 13s - loss: 0.1406 - acc: 0.9521 - val_loss: 0.8157 - val_acc: 0.7659
#
# Epoch 00015: val_loss did not improve from 0.44040
# Epoch 16/20
#  - 13s - loss: 0.1273 - acc: 0.9582 - val_loss: 0.8634 - val_acc: 0.7583
#
# Epoch 00016: val_loss did not improve from 0.44040
# Epoch 17/20
#  - 13s - loss: 0.1175 - acc: 0.9617 - val_loss: 0.9083 - val_acc: 0.7572
#
# Epoch 00017: val_loss did not improve from 0.44040
# Epoch 18/20
#  - 13s - loss: 0.1078 - acc: 0.9665 - val_loss: 0.9914 - val_acc: 0.7613
#
# Epoch 00018: val_loss did not improve from 0.44040
# Epoch 19/20
#  - 13s - loss: 0.1004 - acc: 0.9690 - val_loss: 1.0089 - val_acc: 0.7564
#
# Epoch 00019: val_loss did not improve from 0.44040
# Epoch 20/20
#  - 13s - loss: 0.0909 - acc: 0.9744 - val_loss: 1.1001 - val_acc: 0.7591
#
# Epoch 00020: val_loss did not improve from 0.44040
# Optimal F1: 0.7026 at threshold: 0.2829
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 14s - loss: 0.5366 - acc: 0.7334 - val_loss: 0.4531 - val_acc: 0.7908
#
# Epoch 00001: val_loss improved from inf to 0.45310, saving model to Models/lstm_attention_weights_best.h5
# Epoch 2/20
#  - 13s - loss: 0.4526 - acc: 0.7891 - val_loss: 0.4457 - val_acc: 0.7912
#
# Epoch 00002: val_loss improved from 0.45310 to 0.44570, saving model to Models/lstm_attention_weights_best.h5
# Epoch 3/20
#  - 13s - loss: 0.4305 - acc: 0.8016 - val_loss: 0.4447 - val_acc: 0.7904
#
# Epoch 00003: val_loss improved from 0.44570 to 0.44467, saving model to Models/lstm_attention_weights_best.h5
# Epoch 4/20
#  - 13s - loss: 0.4188 - acc: 0.8064 - val_loss: 0.4389 - val_acc: 0.7995
#
# Epoch 00004: val_loss improved from 0.44467 to 0.43887, saving model to Models/lstm_attention_weights_best.h5
# Epoch 5/20
#  - 13s - loss: 0.3992 - acc: 0.8175 - val_loss: 0.4325 - val_acc: 0.8029
#
# Epoch 00005: val_loss improved from 0.43887 to 0.43247, saving model to Models/lstm_attention_weights_best.h5
# Epoch 6/20
#  - 13s - loss: 0.3783 - acc: 0.8292 - val_loss: 0.4387 - val_acc: 0.7900
#
# Epoch 00006: val_loss did not improve from 0.43247
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 7/20
#  - 13s - loss: 0.3319 - acc: 0.8556 - val_loss: 0.4894 - val_acc: 0.7938
#
# Epoch 00007: val_loss did not improve from 0.43247
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 8/20
#  - 13s - loss: 0.2904 - acc: 0.8752 - val_loss: 0.5168 - val_acc: 0.7783
#
# Epoch 00008: val_loss did not improve from 0.43247
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 9/20
#  - 13s - loss: 0.2433 - acc: 0.9012 - val_loss: 0.5787 - val_acc: 0.7753
#
# Epoch 00009: val_loss did not improve from 0.43247
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 10/20
#  - 13s - loss: 0.2028 - acc: 0.9205 - val_loss: 0.6605 - val_acc: 0.7734
#
# Epoch 00010: val_loss did not improve from 0.43247
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 11/20
#  - 13s - loss: 0.1800 - acc: 0.9326 - val_loss: 0.7090 - val_acc: 0.7674
#
# Epoch 00011: val_loss did not improve from 0.43247
# Epoch 12/20
#  - 13s - loss: 0.1617 - acc: 0.9417 - val_loss: 0.7652 - val_acc: 0.7704
#
# Epoch 00012: val_loss did not improve from 0.43247
# Epoch 13/20
#  - 13s - loss: 0.1488 - acc: 0.9469 - val_loss: 0.7726 - val_acc: 0.7659
#
# Epoch 00013: val_loss did not improve from 0.43247
# Epoch 14/20
#  - 13s - loss: 0.1370 - acc: 0.9527 - val_loss: 0.8395 - val_acc: 0.7674
#
# Epoch 00014: val_loss did not improve from 0.43247
# Epoch 15/20
#  - 13s - loss: 0.1259 - acc: 0.9583 - val_loss: 0.8661 - val_acc: 0.7647
#
# Epoch 00015: val_loss did not improve from 0.43247
# Epoch 16/20
#  - 13s - loss: 0.1131 - acc: 0.9616 - val_loss: 0.9443 - val_acc: 0.7613
#
# Epoch 00016: val_loss did not improve from 0.43247
# Epoch 17/20
#  - 13s - loss: 0.1058 - acc: 0.9664 - val_loss: 0.9259 - val_acc: 0.7598
#
# Epoch 00017: val_loss did not improve from 0.43247
# Epoch 18/20
#  - 13s - loss: 0.0949 - acc: 0.9688 - val_loss: 1.0353 - val_acc: 0.7617
#
# Epoch 00018: val_loss did not improve from 0.43247
# Epoch 19/20
#  - 13s - loss: 0.0866 - acc: 0.9719 - val_loss: 1.0557 - val_acc: 0.7655
#
# Epoch 00019: val_loss did not improve from 0.43247
# Epoch 20/20
#  - 13s - loss: 0.0863 - acc: 0.9715 - val_loss: 1.0886 - val_acc: 0.7557
#
# Epoch 00020: val_loss did not improve from 0.43247
# Optimal F1: 0.7068 at threshold: 0.3250
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 14s - loss: 0.5525 - acc: 0.7202 - val_loss: 0.4897 - val_acc: 0.7651
#
# Epoch 00001: val_loss improved from inf to 0.48971, saving model to Models/lstm_attention_weights_best.h5
# Epoch 2/20
#  - 13s - loss: 0.4499 - acc: 0.7933 - val_loss: 0.4464 - val_acc: 0.7855
#
# Epoch 00002: val_loss improved from 0.48971 to 0.44642, saving model to Models/lstm_attention_weights_best.h5
# Epoch 3/20
#  - 13s - loss: 0.4329 - acc: 0.7969 - val_loss: 0.4480 - val_acc: 0.7889
#
# Epoch 00003: val_loss did not improve from 0.44642
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/20
#  - 13s - loss: 0.4084 - acc: 0.8118 - val_loss: 0.4383 - val_acc: 0.7961
#
# Epoch 00004: val_loss improved from 0.44642 to 0.43835, saving model to Models/lstm_attention_weights_best.h5
# Epoch 5/20
#  - 13s - loss: 0.3940 - acc: 0.8198 - val_loss: 0.4585 - val_acc: 0.7810
#
# Epoch 00005: val_loss did not improve from 0.43835
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 6/20
#  - 13s - loss: 0.3724 - acc: 0.8306 - val_loss: 0.4570 - val_acc: 0.7908
#
# Epoch 00006: val_loss did not improve from 0.43835
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 7/20
#  - 13s - loss: 0.3460 - acc: 0.8444 - val_loss: 0.4598 - val_acc: 0.7885
#
# Epoch 00007: val_loss did not improve from 0.43835
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 8/20
#  - 13s - loss: 0.3223 - acc: 0.8580 - val_loss: 0.4801 - val_acc: 0.7866
#
# Epoch 00008: val_loss did not improve from 0.43835
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 9/20
#  - 13s - loss: 0.3041 - acc: 0.8658 - val_loss: 0.5067 - val_acc: 0.7878
#
# Epoch 00009: val_loss did not improve from 0.43835
# Epoch 10/20
#  - 13s - loss: 0.2892 - acc: 0.8776 - val_loss: 0.5197 - val_acc: 0.7787
#
# Epoch 00010: val_loss did not improve from 0.43835
# Epoch 11/20
#  - 13s - loss: 0.2755 - acc: 0.8834 - val_loss: 0.5518 - val_acc: 0.7764
#
# Epoch 00011: val_loss did not improve from 0.43835
# Epoch 12/20
#  - 13s - loss: 0.2643 - acc: 0.8905 - val_loss: 0.5661 - val_acc: 0.7700
#
# Epoch 00012: val_loss did not improve from 0.43835
# Epoch 13/20
#  - 13s - loss: 0.2474 - acc: 0.8985 - val_loss: 0.5797 - val_acc: 0.7768
#
# Epoch 00013: val_loss did not improve from 0.43835
# Epoch 14/20
#  - 13s - loss: 0.2343 - acc: 0.9077 - val_loss: 0.6267 - val_acc: 0.7674
#
# Epoch 00014: val_loss did not improve from 0.43835
# Epoch 15/20
#  - 13s - loss: 0.2186 - acc: 0.9161 - val_loss: 0.6465 - val_acc: 0.7655
#
# Epoch 00015: val_loss did not improve from 0.43835
# Epoch 16/20
#  - 13s - loss: 0.2066 - acc: 0.9210 - val_loss: 0.6515 - val_acc: 0.7621
#
# Epoch 00016: val_loss did not improve from 0.43835
# Epoch 17/20
#  - 13s - loss: 0.1935 - acc: 0.9265 - val_loss: 0.7048 - val_acc: 0.7708
#
# Epoch 00017: val_loss did not improve from 0.43835
# Epoch 18/20
#  - 13s - loss: 0.1824 - acc: 0.9306 - val_loss: 0.7016 - val_acc: 0.7670
#
# Epoch 00018: val_loss did not improve from 0.43835
# Epoch 19/20
#  - 13s - loss: 0.1726 - acc: 0.9361 - val_loss: 0.7504 - val_acc: 0.7587
#
# Epoch 00019: val_loss did not improve from 0.43835
# Epoch 20/20
#  - 13s - loss: 0.1646 - acc: 0.9403 - val_loss: 0.7601 - val_acc: 0.7606
#
# Epoch 00020: val_loss did not improve from 0.43835
# Optimal F1: 0.7018 at threshold: 0.3252

# %% [markdown]
# Converting the predictions for integer.

# %%
y_test = y_test.reshape((-1, 1))
pred_test_y = (y_test>np.mean(bestscore)).astype(int)
test['predictions'] = le.inverse_transform(pred_test_y)
# Out:
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/sklearn/preprocessing/label.py:273: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(test["subtask_a"], test['predictions']).ravel()
(tn, fp, fn, tp)
# Out:
# (546, 74, 71, 169)

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test["subtask_a"], test['predictions'])
# Out:
# 0.8313953488372093
