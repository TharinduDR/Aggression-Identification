# %% [markdown]
# ## Offensive Language Identification
#
# This is the task 'a' in Task 6: OffensEval: Identifying and Categorizing Offensive Language in Social Media in SemEval 2019. We have explored how a pooled GRU can be used in Offensive language identification.

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn import metrics

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import *
from keras.models import *
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.initializers import *
from keras.optimizers import *
import keras.backend as K
from keras.callbacks import *
import tensorflow as tf
import os
import time
import gc
import re
from unidecode import unidecode
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Get reproducable results

# %%
from numpy.random import seed
from tensorflow import set_random_seed

seed(726)
set_random_seed(726)

# %% [markdown]
# ### Loading the training and testing files

# %%
train = pd.read_csv("Data/training/offenseval-training-v1.tsv", sep='\t')

test_tweets = pd.read_csv("Data/testing/testset-taska.tsv", sep='\t')
test_labels = pd.read_csv("Data/testing/labels-test-a.csv", header=-1, names = ["id", "subtask_a"])

test = pd.merge(test_tweets, test_labels, on=['id','id'])
print("Train shape : ", train.shape)
print("Test shape : ", test.shape)
# Out:
# Train shape :  (13240, 5)
# Test shape :  (860, 3)

# %% [markdown]
# Changing case of the tweets to lower case, since the embedding model only has lower case words

# %%
train["tweet"] = train["tweet"].str.lower()
test["tweet"] = test["tweet"].str.lower()

# %% [markdown]
# cleaning the puncutation marks

# %%
puncts = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£', 
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', 
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', 
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', 
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√', ]

def clean_text(x):

    x = str(x)
    for punct in puncts:
        x = x.replace(punct, f' {punct} ')
    return x


train["tweet"] = train["tweet"].apply(lambda x: clean_text(x))
test["tweet"] = test["tweet"].apply(lambda x: clean_text(x))

# %%
## some config values 
embed_size = 300 # how big is each word vector
max_features = None # how many unique words to use (i.e num rows in embedding vector)
maxlen = 72 # max number of words in a question to use #99.99%

## fill up the missing values
X = train["tweet"].fillna("_na_").values
X_test = test["tweet"].fillna("_na_").values

## Tokenize the sentences
tokenizer = Tokenizer(num_words=max_features, filters='')
tokenizer.fit_on_texts(list(X))

X = tokenizer.texts_to_sequences(X)
X_test = tokenizer.texts_to_sequences(X_test)

## Pad the sentences 
X = pad_sequences(X, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

## Get the target values
Y = train['subtask_a'].values
Y
# Out:
# array(['OFF', 'OFF', 'NOT', ..., 'OFF', 'OFF', 'NOT'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(Y)
encoded_Y = le.transform(Y)
encoded_Y
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %% [markdown]
# Building the Embedding matrix

# %%
word_index = tokenizer.word_index
max_features = len(word_index)+1
def load_glove(word_index):
    EMBEDDING_FILE = '/data/glove/glove.840B.300d.txt'
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if o.split(" ")[0] in word_index)

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    embedding_matrix = np.random.normal(emb_mean, emb_std, (max_features, embed_size))
    for word, i in word_index.items():
        if i >= max_features: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector
            
    return embedding_matrix 
    
def load_fasttext(word_index):    
    EMBEDDING_FILE = '/data/fasttext/crawl-300d-2M-subword.vec'
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if len(o)>100 and o.split(" ")[0] in word_index )

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    embedding_matrix = np.random.normal(emb_mean, emb_std, (max_features, embed_size))
    for word, i in word_index.items():
        if i >= max_features: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector

    return embedding_matrix

# %% [markdown]
# Only Glove vectors have been used in embedding matrix. Can explore it further in future

# %%
embedding_matrix = load_glove(word_index)

# %%
def get_model():
    inp = Input(shape=(maxlen, ))
    x = Embedding(max_features, embed_size, weights=[embedding_matrix])(inp)
    x = SpatialDropout1D(0.2)(x)
    x = Bidirectional(GRU(80, return_sequences=True))(x)
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    conc = concatenate([avg_pool, max_pool])
    outp = Dense(1, activation="sigmoid")(conc)
    
    model = Model(inputs=inp, outputs=outp)
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    return model

# %%
def f1_smart(y_true, y_pred):
    args = np.argsort(y_pred)
    tp = y_true.sum()
    fs = (tp - np.cumsum(y_true[args[:-1]])) / np.arange(y_true.shape[0] + tp - 1, tp, -1)
    res_idx = np.argmax(fs)
    return 2 * fs[res_idx], (y_pred[args[res_idx]] + y_pred[args[res_idx + 1]]) / 2

# %% [markdown]
# Training with early stopping and reducing learning rate on plateu. In each fold values for the test set is also predicted, And after the process, predicted values for the test file would be mean from each fold

# %%
kfold = StratifiedKFold(n_splits=5, random_state=10, shuffle=True)
bestscore = []
y_test = np.zeros((X_test.shape[0], ))
for i, (train_index, valid_index) in enumerate(kfold.split(X, encoded_Y)):
    X_train, X_val, Y_train, Y_val = X[train_index], X[valid_index], encoded_Y[train_index], encoded_Y[valid_index]
    filepath="Models/cnn_weights_best.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=2, save_best_only=True, mode='min')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.6, patience=1, min_lr=0.0001, verbose=2)
    earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=2, mode='auto')
    callbacks = [checkpoint, reduce_lr]
    model = get_model()
    if i == 0:print(model.summary()) 
    model.fit(X_train, Y_train, batch_size=64, epochs=20, validation_data=(X_val, Y_val), verbose=2, callbacks=callbacks, 
             )
    model.load_weights(filepath)
    y_pred = model.predict([X_val], batch_size=64, verbose=2)
    y_test += np.squeeze(model.predict([X_test], batch_size=64, verbose=2))/5
    f1, threshold = f1_smart(np.squeeze(Y_val), np.squeeze(y_pred))
    print('Optimal F1: {:.4f} at threshold: {:.4f}'.format(f1, threshold))
    bestscore.append(threshold)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 72)           0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 72, 300)      6036600     input_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 72, 300)      0           embedding_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 72, 160)      182880      spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 160)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 160)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 320)          0           global_average_pooling1d_2[0][0]
#                                                                  global_max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            321         concatenate_2[0][0]
# ==================================================================================================
# Total params: 6,219,801
# Trainable params: 6,219,801
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 16s - loss: 0.5213 - acc: 0.7442 - val_loss: 0.4435 - val_acc: 0.7961
#
# Epoch 00001: val_loss improved from inf to 0.44347, saving model to Models/cnn_weights_best.h5
# Epoch 2/20
#  - 15s - loss: 0.4110 - acc: 0.8111 - val_loss: 0.4376 - val_acc: 0.7991
#
# Epoch 00002: val_loss improved from 0.44347 to 0.43761, saving model to Models/cnn_weights_best.h5
# Epoch 3/20
#  - 15s - loss: 0.3499 - acc: 0.8435 - val_loss: 0.4581 - val_acc: 0.7968
#
# Epoch 00003: val_loss did not improve from 0.43761
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/20
#  - 16s - loss: 0.2683 - acc: 0.8903 - val_loss: 0.5129 - val_acc: 0.7761
#
# Epoch 00004: val_loss did not improve from 0.43761
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 5/20
#  - 16s - loss: 0.2033 - acc: 0.9190 - val_loss: 0.5647 - val_acc: 0.7730
#
# Epoch 00005: val_loss did not improve from 0.43761
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 6/20
#  - 16s - loss: 0.1657 - acc: 0.9386 - val_loss: 0.6205 - val_acc: 0.7598
#
# Epoch 00006: val_loss did not improve from 0.43761
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 7/20
#  - 16s - loss: 0.1497 - acc: 0.9442 - val_loss: 0.6310 - val_acc: 0.7632
#
# Epoch 00007: val_loss did not improve from 0.43761
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 8/20
#  - 15s - loss: 0.1345 - acc: 0.9505 - val_loss: 0.6728 - val_acc: 0.7613
#
# Epoch 00008: val_loss did not improve from 0.43761
# Epoch 9/20
#  - 15s - loss: 0.1284 - acc: 0.9559 - val_loss: 0.6886 - val_acc: 0.7587
#
# Epoch 00009: val_loss did not improve from 0.43761
# Epoch 10/20
#  - 16s - loss: 0.1198 - acc: 0.9563 - val_loss: 0.7216 - val_acc: 0.7591
#
# Epoch 00010: val_loss did not improve from 0.43761
# Epoch 11/20
#  - 16s - loss: 0.1163 - acc: 0.9586 - val_loss: 0.7307 - val_acc: 0.7572
#
# Epoch 00011: val_loss did not improve from 0.43761
# Epoch 12/20
#  - 15s - loss: 0.1089 - acc: 0.9610 - val_loss: 0.7448 - val_acc: 0.7530
#
# Epoch 00012: val_loss did not improve from 0.43761
# Epoch 13/20
#  - 15s - loss: 0.1024 - acc: 0.9639 - val_loss: 0.7707 - val_acc: 0.7560
#
# Epoch 00013: val_loss did not improve from 0.43761
# Epoch 14/20
#  - 16s - loss: 0.0965 - acc: 0.9670 - val_loss: 0.7985 - val_acc: 0.7526
#
# Epoch 00014: val_loss did not improve from 0.43761
# Epoch 15/20
#  - 15s - loss: 0.0918 - acc: 0.9686 - val_loss: 0.8117 - val_acc: 0.7458
#
# Epoch 00015: val_loss did not improve from 0.43761
# Epoch 16/20
#  - 15s - loss: 0.0924 - acc: 0.9678 - val_loss: 0.8271 - val_acc: 0.7481
#
# Epoch 00016: val_loss did not improve from 0.43761
# Epoch 17/20
#  - 16s - loss: 0.0860 - acc: 0.9700 - val_loss: 0.8310 - val_acc: 0.7481
#
# Epoch 00017: val_loss did not improve from 0.43761
# Epoch 18/20
#  - 16s - loss: 0.0771 - acc: 0.9731 - val_loss: 0.8706 - val_acc: 0.7462
#
# Epoch 00018: val_loss did not improve from 0.43761
# Epoch 19/20
#  - 15s - loss: 0.0768 - acc: 0.9721 - val_loss: 0.8806 - val_acc: 0.7458
#
# Epoch 00019: val_loss did not improve from 0.43761
# Epoch 20/20
#  - 15s - loss: 0.0744 - acc: 0.9739 - val_loss: 0.8937 - val_acc: 0.7417
#
# Epoch 00020: val_loss did not improve from 0.43761
# Optimal F1: 0.6998 at threshold: 0.2929
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 16s - loss: 0.5200 - acc: 0.7473 - val_loss: 0.4537 - val_acc: 0.7829
#
# Epoch 00001: val_loss improved from inf to 0.45374, saving model to Models/cnn_weights_best.h5
# Epoch 2/20
#  - 16s - loss: 0.4103 - acc: 0.8129 - val_loss: 0.4531 - val_acc: 0.7927
#
# Epoch 00002: val_loss improved from 0.45374 to 0.45308, saving model to Models/cnn_weights_best.h5
# Epoch 3/20
#  - 16s - loss: 0.3441 - acc: 0.8476 - val_loss: 0.4916 - val_acc: 0.7730
#
# Epoch 00003: val_loss did not improve from 0.45308
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/20
#  - 17s - loss: 0.2573 - acc: 0.8950 - val_loss: 0.5443 - val_acc: 0.7791
#
# Epoch 00004: val_loss did not improve from 0.45308
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 5/20
#  - 17s - loss: 0.1869 - acc: 0.9285 - val_loss: 0.6078 - val_acc: 0.7727
#
# Epoch 00005: val_loss did not improve from 0.45308
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 6/20
#  - 17s - loss: 0.1544 - acc: 0.9438 - val_loss: 0.6514 - val_acc: 0.7651
#
# Epoch 00006: val_loss did not improve from 0.45308
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 7/20
#  - 16s - loss: 0.1289 - acc: 0.9537 - val_loss: 0.7099 - val_acc: 0.7511
#
# Epoch 00007: val_loss did not improve from 0.45308
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 8/20
#  - 16s - loss: 0.1226 - acc: 0.9562 - val_loss: 0.7206 - val_acc: 0.7553
#
# Epoch 00008: val_loss did not improve from 0.45308
# Epoch 9/20
#  - 16s - loss: 0.1167 - acc: 0.9591 - val_loss: 0.7357 - val_acc: 0.7530
#
# Epoch 00009: val_loss did not improve from 0.45308
# Epoch 10/20
#  - 16s - loss: 0.1075 - acc: 0.9603 - val_loss: 0.7684 - val_acc: 0.7451
#
# Epoch 00010: val_loss did not improve from 0.45308
# Epoch 11/20
#  - 16s - loss: 0.1031 - acc: 0.9627 - val_loss: 0.7887 - val_acc: 0.7515
#
# Epoch 00011: val_loss did not improve from 0.45308
# Epoch 12/20
#  - 16s - loss: 0.0981 - acc: 0.9647 - val_loss: 0.8062 - val_acc: 0.7481
# Epoch 00012: val_loss did not improve from 0.45308
# Epoch 13/20
#  - 17s - loss: 0.0881 - acc: 0.9691 - val_loss: 0.8442 - val_acc: 0.7466
#
# Epoch 00013: val_loss did not improve from 0.45308
# Epoch 14/20
#  - 17s - loss: 0.0840 - acc: 0.9705 - val_loss: 0.8691 - val_acc: 0.7406
#
# Epoch 00014: val_loss did not improve from 0.45308
# Epoch 15/20
#  - 16s - loss: 0.0790 - acc: 0.9721 - val_loss: 0.8955 - val_acc: 0.7436
#
# Epoch 00015: val_loss did not improve from 0.45308
# Epoch 16/20
#  - 17s - loss: 0.0776 - acc: 0.9728 - val_loss: 0.9273 - val_acc: 0.7413
#
# Epoch 00016: val_loss did not improve from 0.45308
# Epoch 17/20
#  - 16s - loss: 0.0770 - acc: 0.9727 - val_loss: 0.9213 - val_acc: 0.7372
#
# Epoch 00017: val_loss did not improve from 0.45308
# Epoch 18/20
#  - 17s - loss: 0.0719 - acc: 0.9754 - val_loss: 0.9571 - val_acc: 0.7383
#
# Epoch 00018: val_loss did not improve from 0.45308
# Epoch 19/20
#  - 16s - loss: 0.0693 - acc: 0.9759 - val_loss: 0.9650 - val_acc: 0.7353
#
# Epoch 00019: val_loss did not improve from 0.45308
# Epoch 20/20
#  - 16s - loss: 0.0637 - acc: 0.9786 - val_loss: 0.9778 - val_acc: 0.7360
#
# Epoch 00020: val_loss did not improve from 0.45308
# Optimal F1: 0.6911 at threshold: 0.2733
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 16s - loss: 0.5211 - acc: 0.7427 - val_loss: 0.4373 - val_acc: 0.7934
#
# Epoch 00001: val_loss improved from inf to 0.43733, saving model to Models/cnn_weights_best.h5
# Epoch 2/20
#  - 15s - loss: 0.4142 - acc: 0.8080 - val_loss: 0.4328 - val_acc: 0.7987
#
# Epoch 00002: val_loss improved from 0.43733 to 0.43280, saving model to Models/cnn_weights_best.h5
# Epoch 3/20
#  - 15s - loss: 0.3538 - acc: 0.8453 - val_loss: 0.4499 - val_acc: 0.7893
#
# Epoch 00003: val_loss did not improve from 0.43280
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/20
#  - 16s - loss: 0.2777 - acc: 0.8826 - val_loss: 0.4774 - val_acc: 0.7931
#
# Epoch 00004: val_loss did not improve from 0.43280
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 5/20
#  - 15s - loss: 0.2177 - acc: 0.9154 - val_loss: 0.5261 - val_acc: 0.7779
#
# Epoch 00005: val_loss did not improve from 0.43280
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 6/20
#  - 15s - loss: 0.1822 - acc: 0.9338 - val_loss: 0.5555 - val_acc: 0.7757
#
# Epoch 00006: val_loss did not improve from 0.43280
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 7/20
#  - 16s - loss: 0.1603 - acc: 0.9400 - val_loss: 0.5833 - val_acc: 0.7742
#
# Epoch 00007: val_loss did not improve from 0.43280
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 8/20
#  - 16s - loss: 0.1458 - acc: 0.9468 - val_loss: 0.6070 - val_acc: 0.7764
#
# Epoch 00008: val_loss did not improve from 0.43280
# Epoch 9/20
#  - 15s - loss: 0.1385 - acc: 0.9498 - val_loss: 0.6268 - val_acc: 0.7685
#
# Epoch 00009: val_loss did not improve from 0.43280
# Epoch 10/20
#  - 15s - loss: 0.1323 - acc: 0.9524 - val_loss: 0.6429 - val_acc: 0.7738
#
# Epoch 00010: val_loss did not improve from 0.43280
# Epoch 11/20
#  - 15s - loss: 0.1242 - acc: 0.9555 - val_loss: 0.6674 - val_acc: 0.7628
#
# Epoch 00011: val_loss did not improve from 0.43280
# Epoch 12/20
#  - 16s - loss: 0.1176 - acc: 0.9585 - val_loss: 0.6850 - val_acc: 0.7628
#
# Epoch 00012: val_loss did not improve from 0.43280
# Epoch 13/20
#  - 17s - loss: 0.1105 - acc: 0.9615 - val_loss: 0.7094 - val_acc: 0.7610
#
# Epoch 00013: val_loss did not improve from 0.43280
# Epoch 14/20
#  - 17s - loss: 0.1091 - acc: 0.9605 - val_loss: 0.7313 - val_acc: 0.7670
#
# Epoch 00014: val_loss did not improve from 0.43280
# Epoch 15/20
#  - 15s - loss: 0.1026 - acc: 0.9636 - val_loss: 0.7486 - val_acc: 0.7568
#
# Epoch 00015: val_loss did not improve from 0.43280
# Epoch 16/20
#  - 16s - loss: 0.0956 - acc: 0.9653 - val_loss: 0.7637 - val_acc: 0.7598
#
# Epoch 00016: val_loss did not improve from 0.43280
# Epoch 17/20
#  - 16s - loss: 0.0917 - acc: 0.9663 - val_loss: 0.7718 - val_acc: 0.7579
#
# Epoch 00017: val_loss did not improve from 0.43280
# Epoch 18/20
#  - 16s - loss: 0.0869 - acc: 0.9703 - val_loss: 0.8046 - val_acc: 0.7545
#
# Epoch 00018: val_loss did not improve from 0.43280
# Epoch 19/20
#  - 16s - loss: 0.0811 - acc: 0.9720 - val_loss: 0.8190 - val_acc: 0.7530
#
# Epoch 00019: val_loss did not improve from 0.43280
# Epoch 20/20
#  - 16s - loss: 0.0828 - acc: 0.9707 - val_loss: 0.8324 - val_acc: 0.7557
#
# Epoch 00020: val_loss did not improve from 0.43280
# Optimal F1: 0.7137 at threshold: 0.3368
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 17s - loss: 0.5241 - acc: 0.7450 - val_loss: 0.4409 - val_acc: 0.7961
#
# Epoch 00001: val_loss improved from inf to 0.44085, saving model to Models/cnn_weights_best.h5
# Epoch 2/20
#  - 16s - loss: 0.4209 - acc: 0.8085 - val_loss: 0.4325 - val_acc: 0.7998
#
# Epoch 00002: val_loss improved from 0.44085 to 0.43247, saving model to Models/cnn_weights_best.h5
# Epoch 3/20
#  - 17s - loss: 0.3552 - acc: 0.8411 - val_loss: 0.4427 - val_acc: 0.7949
#
# Epoch 00003: val_loss did not improve from 0.43247
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/20
#  - 16s - loss: 0.2724 - acc: 0.8887 - val_loss: 0.4805 - val_acc: 0.7749
#
# Epoch 00004: val_loss did not improve from 0.43247
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 5/20
#  - 16s - loss: 0.2123 - acc: 0.9164 - val_loss: 0.5300 - val_acc: 0.7727
#
# Epoch 00005: val_loss did not improve from 0.43247
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 6/20
#  - 16s - loss: 0.1719 - acc: 0.9351 - val_loss: 0.6050 - val_acc: 0.7613
#
# Epoch 00006: val_loss did not improve from 0.43247
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 7/20
#  - 16s - loss: 0.1492 - acc: 0.9436 - val_loss: 0.6132 - val_acc: 0.7659
#
# Epoch 00007: val_loss did not improve from 0.43247
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 8/20
#  - 16s - loss: 0.1391 - acc: 0.9492 - val_loss: 0.6411 - val_acc: 0.7610
#
# Epoch 00008: val_loss did not improve from 0.43247
# Epoch 9/20
#  - 16s - loss: 0.1312 - acc: 0.9519 - val_loss: 0.6646 - val_acc: 0.7636
#
# Epoch 00009: val_loss did not improve from 0.43247
# Epoch 10/20
#  - 16s - loss: 0.1215 - acc: 0.9560 - val_loss: 0.6817 - val_acc: 0.7583
#
# Epoch 00010: val_loss did not improve from 0.43247
# Epoch 11/20
#  - 16s - loss: 0.1170 - acc: 0.9573 - val_loss: 0.6909 - val_acc: 0.7579
#
# Epoch 00011: val_loss did not improve from 0.43247
# Epoch 12/20
#  - 16s - loss: 0.1123 - acc: 0.9591 - val_loss: 0.7199 - val_acc: 0.7576
#
# Epoch 00012: val_loss did not improve from 0.43247
# Epoch 13/20
#  - 16s - loss: 0.1027 - acc: 0.9644 - val_loss: 0.7363 - val_acc: 0.7560
#
# Epoch 00013: val_loss did not improve from 0.43247
# Epoch 14/20
#  - 16s - loss: 0.0964 - acc: 0.9654 - val_loss: 0.7605 - val_acc: 0.7568
#
# Epoch 00014: val_loss did not improve from 0.43247
# Epoch 15/20
#  - 15s - loss: 0.0958 - acc: 0.9660 - val_loss: 0.7701 - val_acc: 0.7583
#
# Epoch 00015: val_loss did not improve from 0.43247
# Epoch 16/20
#  - 16s - loss: 0.0910 - acc: 0.9673 - val_loss: 0.7869 - val_acc: 0.7572
#
# Epoch 00016: val_loss did not improve from 0.43247
# Epoch 17/20
#  - 16s - loss: 0.0873 - acc: 0.9683 - val_loss: 0.8079 - val_acc: 0.7511
#
# Epoch 00017: val_loss did not improve from 0.43247
# Epoch 18/20
#  - 16s - loss: 0.0791 - acc: 0.9717 - val_loss: 0.8296 - val_acc: 0.7534
#
# Epoch 00018: val_loss did not improve from 0.43247
# Epoch 19/20
#  - 16s - loss: 0.0763 - acc: 0.9727 - val_loss: 0.8651 - val_acc: 0.7481
#
# Epoch 00019: val_loss did not improve from 0.43247
# Epoch 20/20
#  - 16s - loss: 0.0740 - acc: 0.9738 - val_loss: 0.8710 - val_acc: 0.7489
#
# Epoch 00020: val_loss did not improve from 0.43247
# Optimal F1: 0.6975 at threshold: 0.4022
# Train on 10592 samples, validate on 2648 samples
# Epoch 1/20
#  - 17s - loss: 0.5255 - acc: 0.7389 - val_loss: 0.4601 - val_acc: 0.7813
#
# Epoch 00001: val_loss improved from inf to 0.46007, saving model to Models/cnn_weights_best.h5
# Epoch 2/20
#  - 16s - loss: 0.4151 - acc: 0.8081 - val_loss: 0.4395 - val_acc: 0.7965
#
# Epoch 00002: val_loss improved from 0.46007 to 0.43954, saving model to Models/cnn_weights_best.h5
# Epoch 3/20
#  - 16s - loss: 0.3567 - acc: 0.8404 - val_loss: 0.4571 - val_acc: 0.7976
#
# Epoch 00003: val_loss did not improve from 0.43954
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# Epoch 4/20
#  - 16s - loss: 0.2736 - acc: 0.8830 - val_loss: 0.5067 - val_acc: 0.7851
#
# Epoch 00004: val_loss did not improve from 0.43954
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# Epoch 5/20
#  - 16s - loss: 0.2120 - acc: 0.9157 - val_loss: 0.5550 - val_acc: 0.7806
#
# Epoch 00005: val_loss did not improve from 0.43954
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# Epoch 6/20
#  - 16s - loss: 0.1738 - acc: 0.9335 - val_loss: 0.6169 - val_acc: 0.7719
#
# Epoch 00006: val_loss did not improve from 0.43954
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# Epoch 7/20
#  - 16s - loss: 0.1537 - acc: 0.9433 - val_loss: 0.6274 - val_acc: 0.7768
#
# Epoch 00007: val_loss did not improve from 0.43954
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 8/20
#  - 16s - loss: 0.1414 - acc: 0.9478 - val_loss: 0.6611 - val_acc: 0.7738
#
# Epoch 00008: val_loss did not improve from 0.43954
# Epoch 9/20
#  - 16s - loss: 0.1310 - acc: 0.9496 - val_loss: 0.6695 - val_acc: 0.7715
#
# Epoch 00009: val_loss did not improve from 0.43954
# Epoch 10/20
#  - 16s - loss: 0.1213 - acc: 0.9557 - val_loss: 0.6949 - val_acc: 0.7689
#
# Epoch 00010: val_loss did not improve from 0.43954
# Epoch 11/20
#  - 16s - loss: 0.1169 - acc: 0.9574 - val_loss: 0.7094 - val_acc: 0.7670
#
# Epoch 00011: val_loss did not improve from 0.43954
# Epoch 12/20
#  - 16s - loss: 0.1116 - acc: 0.9567 - val_loss: 0.7312 - val_acc: 0.7655
#
# Epoch 00012: val_loss did not improve from 0.43954
# Epoch 13/20
#  - 16s - loss: 0.1062 - acc: 0.9621 - val_loss: 0.7552 - val_acc: 0.7628
#
# Epoch 00013: val_loss did not improve from 0.43954
# Epoch 14/20
#  - 16s - loss: 0.1018 - acc: 0.9624 - val_loss: 0.7598 - val_acc: 0.7617
#
# Epoch 00014: val_loss did not improve from 0.43954
# Epoch 15/20
#  - 15s - loss: 0.0942 - acc: 0.9656 - val_loss: 0.7928 - val_acc: 0.7610
#
# Epoch 00015: val_loss did not improve from 0.43954
# Epoch 16/20
#  - 16s - loss: 0.0900 - acc: 0.9671 - val_loss: 0.7983 - val_acc: 0.7606
#
# Epoch 00016: val_loss did not improve from 0.43954
# Epoch 17/20
#  - 16s - loss: 0.0856 - acc: 0.9697 - val_loss: 0.8414 - val_acc: 0.7587
#
# Epoch 00017: val_loss did not improve from 0.43954
# Epoch 18/20
#  - 16s - loss: 0.0822 - acc: 0.9708 - val_loss: 0.8462 - val_acc: 0.7545
#
# Epoch 00018: val_loss did not improve from 0.43954
# Epoch 19/20
#  - 16s - loss: 0.0774 - acc: 0.9721 - val_loss: 0.8647 - val_acc: 0.7587
#
# Epoch 00019: val_loss did not improve from 0.43954
# Epoch 20/20
#  - 15s - loss: 0.0730 - acc: 0.9743 - val_loss: 0.8948 - val_acc: 0.7568
#
# Epoch 00020: val_loss did not improve from 0.43954
# Optimal F1: 0.6972 at threshold: 0.2572

# %% [markdown]
# Converting the predictions for integer.

# %%
y_test = y_test.reshape((-1, 1))
pred_test_y = (y_test>np.mean(bestscore)).astype(int)
test['predictions'] = le.inverse_transform(pred_test_y)
# Out:
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/sklearn/preprocessing/label.py:273: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(test["subtask_a"], test['predictions']).ravel()
(tn, fp, fn, tp)
# Out:
# (535, 85, 61, 179)

# %%
from visualization.confusion_matrix_pretty_print import plot_confusion_matrix_from_data

columns = []
annot = True
cmap = 'Oranges'
fmt = '.2f'
lw = 0.5
cbar = False
show_null_values = 2
pred_val_axis = 'y'
# size::
fz = 12;
figsize = [9, 9];
if len(y_test) > 10:
    fz = 9;
    figsize = [14, 14];
plot_confusion_matrix_from_data(test["subtask_a"], test['predictions'], columns,
                                    annot, cmap, fmt, fz, lw, cbar, figsize, show_null_values, pred_val_axis)

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test["subtask_a"], test['predictions'])
# Out:
# 0.8302325581395349
